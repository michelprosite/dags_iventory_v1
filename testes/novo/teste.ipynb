# %%
import pandas as pd

# %%
df = pd.read_csv('/home/michel/Documentos/airflow_docker/dags_iventory_v1/data/trusted/df_dags_inventary_all.csv')
df
# Out:
#                         ocorrencia                  task  \
# 0     2023-11-23T18:28:13.687+0000  taskinstance.py:1083
# 1     2023-11-23T18:28:13.706+0000  taskinstance.py:1083
# 2     2023-11-23T18:28:13.707+0000  taskinstance.py:1279
# 3     2023-11-23T18:28:13.707+0000  taskinstance.py:1280
# 4     2023-11-23T18:28:13.708+0000  taskinstance.py:1281
# ...                            ...                   ...
# 1350  2023-11-23T19:26:24.040+0000        manager.py:726
# 1351  2023-11-23T19:26:24.044+0000        manager.py:729
# 1352  2023-11-23T19:26:44.165+0000        manager.py:726
# 1353  2023-11-23T19:26:44.166+0000        manager.py:729
# 1354  2023-11-23T19:26:53.276+0000        manager.py:854
#
#                                                    info
# 0     Dependencies all met for <TaskInstance: extrai...
# 1     Dependencies all met for <TaskInstance: extrai...
# 2                                                   NaN
# ...

# %%
df = pd.read_csv('/home/michel/Documentos/airflow_docker/dags_iventory_v1/data/trusted/df_dags_inventary_id.csv').drop(columns='Unnamed: 0')
df
# Out:
#     airflow_ctx_dag_owner airflow_ctx_dag_id       airflow_ctx_task_id  \
# 0                     ***   extrair_logs_***  process_logs_dag_conexao
# 1                     ***   extrair_logs_***  process_logs_dag_conexao
# 2                     ***   extrair_logs_***  process_logs_dag_conexao
# 3                     ***   extrair_logs_***  process_logs_dag_conexao
# 4                     ***   extrair_logs_***  process_logs_dag_conexao
# ..                    ...                ...                       ...
# 445                   ***   extrair_logs_***  extrair_logs_dag_conexao
# 446                   ***   extrair_logs_***  extrair_logs_dag_conexao
# 447                   ***   extrair_logs_***  extrair_logs_dag_conexao
# 448                   ***   extrair_logs_***  extrair_logs_dag_conexao
# 449                   ***   extrair_logs_***  extrair_logs_dag_conexao
#
#            airflow_ctx_execution_date  airflow_ctx_try_number  \
# ...
